# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\user\Downloads\datasets_4458_8204_winequality-red.csv')

# %%
bool_series = pd.isnull(df)

# %%
df1 = df.dropna()

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()
_= plt.hist(df1['fixed acidity'])
_= plt.xlabel('fixed acidity')
_= plt.ylabel('count')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()
_= plt.hist(df1['volatile acidity'])
_= plt.xlabel('volatile acidity')
_= plt.ylabel('count')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()
_= plt.hist(df1['citric acid'])
_= plt.xlabel('citric acid')
_= plt.ylabel('count')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()
_= plt.hist(df1['residual sugar'])
_= plt.xlabel('residual sugar')
_= plt.ylabel('count')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()
_= plt.hist(df1['chlorides'])
_= plt.xlabel('chlorides')
_= plt.ylabel('count')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
_= sns.boxplot('quality','fixed acidity', data = df1)
_= plt.xlabel('quality')
_= plt.ylabel('fixed acidity')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
_= sns.boxplot('quality','volatile acidity', data = df1)
_= plt.xlabel('quality')
_= plt.ylabel('volatile acidity')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
_= sns.boxplot('quality','citric acid', data = df1)
_= plt.xlabel('quality')
_= plt.ylabel('citric acid ')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
_= sns.boxplot('quality','residual sugar', data = df1)
_= plt.xlabel('quality')
_= plt.ylabel('residual sugar')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
_= sns.boxplot('quality','chlorides', data = df1)
_= plt.xlabel('quality')
_= plt.ylabel('chlorides')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
_= sns.boxplot('quality','free sulfur dioxide', data = df1)
_= plt.xlabel('quality')
_= plt.ylabel('free sulphur dioxide ')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
_= sns.boxplot('quality','total sulfur dioxide', data = df1)
_= plt.xlabel('quality')
_= plt.ylabel('total sulfur dioxide')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
_= sns.boxplot('quality','density', data = df1)
_= plt.xlabel('quality')
_= plt.ylabel('density')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
_= sns.boxplot('quality','pH', data = df1)
_= plt.xlabel('quality')
_= plt.ylabel('ph')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
_= sns.boxplot('quality','sulphates', data = df1)
_= plt.xlabel('quality')
_= plt.ylabel('sulphates')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
_= sns.boxplot('quality','alcohol', data = df1)
_= plt.xlabel('quality')
_= plt.ylabel('alcohol')
plt.show()

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\user\Downloads\datasets_4458_8204_winequality-red.csv')
df1= df.dropna()
import matplotlib.pyplot as plt

X= df1['quality']
Y = df1['fixed acidity']
_= plt.plot(X,Y, marker = '.', linestyle='none')
_= plt.xlabel('quality')
_= plt.ylabel('fixed acidity')

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\user\Downloads\datasets_4458_8204_winequality-red.csv')
df1= df.dropna()
import matplotlib.pyplot as plt

X= df1['quality']
Y = df1['volatile acidity']
_= plt.plot(X,Y, marker = '.', linestyle='none')
_= plt.xlabel('quality')
_= plt.ylabel('volatile accidity')

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\user\Downloads\datasets_4458_8204_winequality-red.csv')
df1= df.dropna()
import matplotlib.pyplot as plt

X= df1['quality']
Y = df1['citric acid']
_= plt.plot(X,Y, marker = '.', linestyle='none')
_= plt.xlabel('quality')
_= plt.ylabel('citric acid')

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\user\Downloads\datasets_4458_8204_winequality-red.csv')
df1= df.dropna()
import matplotlib.pyplot as plt

X= df1['quality']
Y = df1['residual sugar']
_= plt.plot(X,Y, marker = '.', linestyle='none')
_= plt.xlabel('quality')
_= plt.ylabel('residual sugar')

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\user\Downloads\datasets_4458_8204_winequality-red.csv')
df1= df.dropna()
import matplotlib.pyplot as plt

X= df1['quality']
Y = df1['chlorides']
_= plt.plot(X,Y, marker = '.', linestyle='none')
_= plt.xlabel('quality')
_= plt.ylabel('chlorides')

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\user\Downloads\datasets_4458_8204_winequality-red.csv')
df.head()
df.info()
y = df['quality']
x= df.drop('quality', axis=1)
type(x)
from sklearn.model_selection import train_test_split
x_train , x_test , y_train ,y_test = train_test_split(x ,y , test_size=.3,random_state=42,stratify =y)
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors= 6)
knn.fit(x_train , y_train)
accuracy=knn.score(x_test,y_test)
print(accuracy)
prediction = knn.predict(x_test)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# 0.5104166666666666
# ...

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\user\Downloads\datasets_4458_8204_winequality-red.csv')
df.head()
y = df['quality']
x= df.drop('quality', axis=1)
from sklearn.model_selection import train_test_split
x_train , x_test , y_train ,y_test = train_test_split(x ,y , test_size=.1,random_state=42)
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train, y_train)
accuracy = reg.score(x_test , y_test)
y_pred = reg.predict(x_test)
print(accuracy)
print(y_pred)
# Out:
# 0.4248840891710032
# [5.34731415 5.08039545 5.64507047 5.45297426 5.73161076 5.28774061
#  5.07091414 5.11492097 5.75984444 5.68738566 6.12449912 5.23158424
#  5.55447514 5.25320972 5.46793041 6.47277211 5.16097593 5.59634284
#  6.56893175 5.32331516 5.38622573 5.19811176 5.94288186 6.36151165
#  5.34581532 5.42971089 6.35499266 5.35950011 5.20740958 6.20114286
#  5.26073028 5.53175321 5.76571448 5.36942941 5.4458297  5.03942962
#  6.19000562 5.69402817 5.62595082 6.174239   5.50755867 5.25507049
#  6.17743276 5.18369697 5.89363669 5.80838546 6.43525343 5.59518381
#  5.13534739 5.5515508  5.19752113 5.14538155 5.56617145 6.36248643
#  4.97689047 5.00052037 6.01649843 5.4441779  5.84444788 5.2566381
#  5.60740066 5.96630397 5.29314622 5.33539883 6.48980963 5.44180649
#  6.35350807 5.25269233 6.42783621 5.32410415 6.42497414 4.74709487
#  5.81280292 5.82726309 6.17569939 5.28962887 6.7760984  5.91839043
#  6.0945725  6.46868513 5.32073974 6.45177735 5.44283907 5.68587542
# ...
