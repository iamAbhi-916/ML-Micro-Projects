# %%
import pandas as pd 
df = pd.read_csv("https://covid.ourworldindata.org/data/owid-covid-data.csv")

# %%
df = df.loc[df['location'] == "India"]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 16388 to 16621
# Data columns (total 40 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         234 non-null    object
#  1   continent                        234 non-null    object
#  2   location                         234 non-null    object
#  3   date                             234 non-null    object
#  4   total_cases                      233 non-null    float64
#  5   new_cases                        233 non-null    float64
#  6   new_cases_smoothed               228 non-null    float64
#  7   total_deaths                     233 non-null    float64
#  8   new_deaths                       233 non-null    float64
#  9   new_deaths_smoothed              228 non-null    float64
#  10  total_cases_per_million          233 non-null    float64
#  11  new_cases_per_million            233 non-null    float64
#  12  new_cases_smoothed_per_million   228 non-null    float64
#  13  total_deaths_per_million         233 non-null    float64
#  14  new_deaths_per_million           233 non-null    float64
#  15  new_deaths_smoothed_per_million  228 non-null    float64
#  16  new_tests                        143 non-null    float64
#  17  total_tests                      149 non-null    float64
#  18  total_tests_per_thousand         149 non-null    float64
#  19  new_tests_per_thousand           143 non-null    float64
#  20  new_tests_smoothed               154 non-null    float64
#  21  new_tests_smoothed_per_thousand  154 non-null    float64
#  22  tests_per_case                   154 non-null    float64
#  23  positive_rate                    154 non-null    float64
#  24  tests_units                      161 non-null    object
#  25  stringency_index                 220 non-null    float64
#  26  population                       234 non-null    float64
#  27  population_density               234 non-null    float64
#  28  median_age                       234 non-null    float64
#  29  aged_65_older                    234 non-null    float64
#  30  aged_70_older                    234 non-null    float64
#  31  gdp_per_capita                   234 non-null    float64
#  32  extreme_poverty                  234 non-null    float64
#  33  cardiovasc_death_rate            234 non-null    float64
#  34  diabetes_prevalence              234 non-null    float64
#  35  female_smokers                   234 non-null    float64
#  36  male_smokers                     234 non-null    float64
#  37  handwashing_facilities           234 non-null    float64
#  38  hospital_beds_per_thousand       234 non-null    float64
#  39  life_expectancy                  234 non-null    float64
# dtypes: float64(35), object(5)
# memory usage: 75.0+ KB

# %%
df["total_cases"].fillna(df["total_cases"].mean(), inplace = True)
df["new_cases"].fillna(df["new_cases"].mean(), inplace = True)
df["new_cases_smoothed"].fillna(df["new_cases_smoothed"].mean(), inplace = True)
df["total_deaths"].fillna(df["total_deaths"].mean(), inplace = True)
df["new_deaths"].fillna(df["new_deaths"].mean(), inplace = True)
df["new_deaths_smoothed"].fillna(df["new_deaths_smoothed"].mean(), inplace = True)
df["total_cases_per_million"].fillna(df["total_cases_per_million"].mean(), inplace = True)
df["new_cases_per_million"].fillna(df["new_cases_per_million"].mean(), inplace = True)
df["new_cases_smoothed_per_million"].fillna(df["new_cases_smoothed_per_million"].mean(), inplace = True)
df["total_deaths_per_million"].fillna(df["total_deaths_per_million"].mean(), inplace = True)
df["new_deaths_per_million"].fillna(df["new_deaths_per_million"].mean(), inplace = True)
df["new_deaths_smoothed_per_million"].fillna(df["new_deaths"].mean(), inplace = True)
df["new_tests"].fillna(df["new_tests"].mean(), inplace = True)
df["total_tests"].fillna(df["total_tests"].mean(), inplace = True)
df["total_tests_per_thousand"].fillna(df["total_tests_per_thousand"].mean(), inplace = True)
df["new_tests_per_thousand"].fillna(df["new_tests_per_thousand"].mean(), inplace = True)
df["new_tests_smoothed"].fillna(df["new_tests_smoothed"].mean(), inplace = True)
df["new_tests_smoothed_per_thousand"].fillna(df["new_tests_smoothed_per_thousand"].mean(), inplace = True)
df["tests_per_case"].fillna(df["tests_per_case"].mean(), inplace = True)
df["positive_rate"].fillna(df["positive_rate"].mean(), inplace = True)
df["tests_units"].fillna(df["tests_units"].mode()[0], inplace = True)
df["stringency_index"].fillna(df["stringency_index"].mean(), inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 16388 to 16621
# Data columns (total 40 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         234 non-null    object
#  1   continent                        234 non-null    object
#  2   location                         234 non-null    object
#  3   date                             234 non-null    object
#  4   total_cases                      234 non-null    float64
#  5   new_cases                        234 non-null    float64
#  6   new_cases_smoothed               234 non-null    float64
#  7   total_deaths                     234 non-null    float64
#  8   new_deaths                       234 non-null    float64
#  9   new_deaths_smoothed              234 non-null    float64
#  10  total_cases_per_million          234 non-null    float64
#  11  new_cases_per_million            234 non-null    float64
#  12  new_cases_smoothed_per_million   234 non-null    float64
#  13  total_deaths_per_million         234 non-null    float64
#  14  new_deaths_per_million           234 non-null    float64
#  15  new_deaths_smoothed_per_million  234 non-null    float64
#  16  new_tests                        234 non-null    float64
#  17  total_tests                      234 non-null    float64
#  18  total_tests_per_thousand         234 non-null    float64
#  19  new_tests_per_thousand           234 non-null    float64
#  20  new_tests_smoothed               234 non-null    float64
#  21  new_tests_smoothed_per_thousand  234 non-null    float64
#  22  tests_per_case                   234 non-null    float64
#  23  positive_rate                    234 non-null    float64
#  24  tests_units                      234 non-null    object
#  25  stringency_index                 234 non-null    float64
#  26  population                       234 non-null    float64
#  27  population_density               234 non-null    float64
#  28  median_age                       234 non-null    float64
#  29  aged_65_older                    234 non-null    float64
#  30  aged_70_older                    234 non-null    float64
#  31  gdp_per_capita                   234 non-null    float64
#  32  extreme_poverty                  234 non-null    float64
#  33  cardiovasc_death_rate            234 non-null    float64
#  34  diabetes_prevalence              234 non-null    float64
#  35  female_smokers                   234 non-null    float64
#  36  male_smokers                     234 non-null    float64
#  37  handwashing_facilities           234 non-null    float64
#  38  hospital_beds_per_thousand       234 non-null    float64
#  39  life_expectancy                  234 non-null    float64
# dtypes: float64(35), object(5)
# memory usage: 75.0+ KB

# %%
import matplotlib.pyplot as plt
plt.hist(df["total_cases"])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df["new_cases"])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df["tests_units"])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df["tests_per_case"])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df["total_deaths"])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df["new_deaths"])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df["total_tests"])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df["new_tests"])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df["aged_65_older"])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df["population"])
plt.show()

# %%
x=df["total_cases"].mean()
y=df["total_cases"].mode()[0]
z=df["total_cases"].median()
print (x,y,z)
# Out:
# 378444.53017241374 0.0 26496.0

# %%
x=df["new_cases"].mean()
y=df["new_cases"].mode()[0]
z=df["new_cases"].median()
print (x,y,z)
# Out:
# 11927.900862068966 0.0 1553.0

# %%
x=df["population"].mean()
y=df["population"].mode()[0]
z=df["population"].median()
print (x,y,z)
# Out:
# 1380004385.0 1380004385.0 1380004385.0

# %%
x=df["total_tests"].mean()
y=df["total_tests"].mode()[0]
z=df["total_tests"].median()
print (x,y,z)
# Out:
# 7692533.540540539 7692533.540540541 7692533.540540541

# %%
x=df["new_deaths"].mean()
y=df["new_deaths"].mode()[0]
z=df["new_deaths"].median()
print (x,y,z)
# Out:
# 227.9698275862069 0.0 50.0

# %%
x=df["tests_per_case"].mean()
y=df["tests_per_case"].mode()[0]
z=df["tests_per_case"].median()
print (x,y,z)
# Out:
# 19.069071895424837 19.069071895424837 19.069071895424837

# %%
import matplotlib.pyplot as plt
y= df["total_cases"]
x = df["new_cases"]
plt.scatter(x,y)
plt.xlabel("new_cases")
plt.ylabel("total_cases")
plt.show()

# %%
import matplotlib.pyplot as plt
y= df["total_cases"]
x = df["total_deaths"]
plt.scatter(x,y)
plt.xlabel("total_deaths")
plt.ylabel("total_cases")
plt.show()

# %%
import matplotlib.pyplot as plt
y= df["total_cases"]
x = df["new_deaths"]
plt.scatter(x,y)
plt.xlabel("new_deaths")
plt.ylabel("total_cases")
plt.show()

# %%
import matplotlib.pyplot as plt
y= df["total_cases"]
x = df["female_smokers"]
plt.scatter(x,y)
plt.xlabel("female_smokers")
plt.ylabel("total_cases")
plt.show()

# %%
import matplotlib.pyplot as plt
y= df["total_cases"]
x = df["male_smokers"]
plt.scatter(x,y)
plt.xlabel("male_smokers")
plt.ylabel("total_cases")
plt.show()

# %%
import matplotlib.pyplot as plt
y= df["total_cases"]
x = df["new_tests"]
plt.scatter(x,y)
plt.xlabel("new_tests")
plt.ylabel("total_cases")
plt.show()

# %%
import matplotlib.pyplot as plt
y= df["total_cases"]
x = df["positive_rate"]
plt.scatter(x,y)
plt.xlabel("positive_rate")
plt.ylabel("total_cases")
plt.show()

# %%
import matplotlib.pyplot as plt
y= df["total_cases"]
x = df["life_expectancy"]
plt.scatter(x,y)
plt.xlabel("life_expectancy")
plt.ylabel("total_cases")
plt.show()

# %%
import matplotlib.pyplot as plt
y= df["total_cases"]
x = df["cardiovasc_death_rate"]
plt.scatter(x,y)
plt.xlabel("cardiovasc_death_rate")
plt.ylabel("total_cases")
plt.show()

# %%
import matplotlib.pyplot as plt
y= df["total_cases"]
x = df["positive_rate"]
plt.plot(x,y)
plt.xlabel("positive_rate")
plt.ylabel("total_cases")
plt.show()

# %%
import matplotlib.pyplot as plt
y= df["total_cases"]
x = df["new_cases"]
plt.plot(x,y)
plt.xlabel("new_cases")
plt.ylabel("total_cases")
plt.show()

# %%
import matplotlib.pyplot as plt
y= df["total_cases"]
x = df["new_deaths"]
plt.plot(x,y)
plt.xlabel("new_deaths")
plt.ylabel("total_cases")
plt.show()

# %%
import matplotlib.pyplot as plt
y= df["total_cases"]
x = df["total_deaths"]
plt.plot(x,y)
plt.xlabel("total_deaths")
plt.ylabel("total_cases")
plt.show()

# %%
import matplotlib.pyplot as plt
y= df["total_cases"]
x = df["male_smokers"]
plt.plot(x,y)
plt.xlabel("male_smokers")
plt.ylabel("total_cases")
plt.show()

# %%
import matplotlib.pyplot as plt
y= df["total_cases"]
x = df["female_smokers"]
plt.plot(x,y)
plt.xlabel("female_smokers")
plt.ylabel("total_cases")
plt.show()

# %%
import matplotlib.pyplot as plt
y= df["total_cases"]
x = df["life_expectancy"]
plt.plot(x,y)
plt.xlabel("life_expectancy")
plt.ylabel("total_cases")
plt.show()

# %%
import matplotlib.pyplot as plt
y= df["total_cases"]
x = df["total_tests"]
plt.plot(x,y)
plt.xlabel("total_tests")
plt.ylabel("total_cases")
plt.show()

# %%
import matplotlib.pyplot as plt
y= df["total_cases"]
x = df["tests_per_case"]
plt.plot(x,y)
plt.xlabel("tests_per_case")
plt.ylabel("total_cases")
plt.show()

# %%
import matplotlib.pyplot as plt
y= df["total_cases"]
x = df["median_age"]
plt.plot(x,y)
plt.xlabel("median_age")
plt.ylabel("total_cases")
plt.show()

# %%
import datetime as dt
df["date"]= pd.to_datetime(df["date"])
df["date"]= df["date"].map(dt.datetime.toordinal)

# %%
x= df.drop(['iso_code','continent','location','total_cases','tests_units'], axis=1 )
y= df['total_cases']
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.3,random_state = 42)
from sklearn.ensemble import RandomForestRegressor 
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0) 
regressor.fit(x_train, y_train)
regressor.score(x_test,y_test)
# Out:
# 0.9976971133466992

# %%
x= df.drop(['iso_code','continent','location','total_cases','tests_units'], axis=1 )
y= df['total_cases']
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.3,random_state = 42)
from sklearn.linear_model import LinearRegression 
regr = LinearRegression() 
regr.fit(x_train,y_train)
regr.score(x_test,y_test)
# Out:
# 2020-08-20 00:00:00
